# %% [markdown]
# <a href="https://colab.research.google.com/github/chriswin17/basics4/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
supermarket=files.upload()
# Out:
#      <input type="file" id="files-a524c06b-1148-44e7-b809-0f412a33938b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a524c06b-1148-44e7-b809-0f412a33938b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
teamsandleagues=files.upload()
# Out:
#      <input type="file" id="files-85634b1b-b3fd-4292-a5cf-163d3121989c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-85634b1b-b3fd-4292-a5cf-163d3121989c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
teamgoals={
    'teams':['Spain','England'],
    'goals':[2,4]
}
teamgoaldf= pd.DataFrame(teamgoals)
print(teamgoaldf)
# Out:
#      teams  goals
# 0    Spain      2
# 1  England      4

# %%
import pandas as pd
teamplayers={
    'players':['Rono','Mess'],
    'country':['Portugal','Argentina']
}
teamplayersdf= pd.DataFrame(teamplayers)
print(teamplayersdf)
# Out:
#   players    country
# 0    Rono   Portugal
# 1    Mess  Argentina

# %%
import pandas as pd
marklist={
    'subject':['Python','C++'],
    'marks':[2,4]
}
marklist= pd.DataFrame(marklist)
print(marklist)
# Out:
#   subject  marks
# 0  Python      2
# 1     C++      4

# %%
import pandas
dataframe=pandas.read_csv("Supermarket_sales.csv")
print(dataframe)
# Out:
#        No    InvoiceID Branch       City Customertype  Gender  \
# 0       1  750-67-8428      A     Yangon       Member  Female
# 1       2  226-31-3081      C  Naypyitaw       Normal  Female
# 2       3  631-41-3108      A     Yangon       Normal    Male
# 3       4  123-19-1176      A     Yangon       Member    Male
# 4       5  373-73-7910      A     Yangon       Normal    Male
# ..    ...          ...    ...        ...          ...     ...
# 995   996  233-67-5758      C  Naypyitaw       Normal    Male
# 996   997  303-96-2227      B   Mandalay       Normal  Female
# 997   998  727-02-1313      A     Yangon       Member    Male
# 998   999  347-56-2442      A     Yangon       Normal    Male
# 999  1000  849-09-3807      A     Yangon       Member  Female
#
#                 Productline  Unitprice  Quantity      Tax      Total  \
# 0         Health and beauty      74.69         7  26.1415   548.9715
# 1    Electronic accessories      15.28         5   3.8200    80.2200
# ...

# %%
import pandas
dataframe=pandas.read_csv("teams_and_leagues.csv")
print(dataframe)
# Out:
#        url                   league_name
# 0      241       Spain Primera Division
# 1       11       English Premier League
# 2        5       English Premier League
# 3      243       Spain Primera Division
# 4        1       English Premier League
# ...    ...                           ...
# 1075   326            Turkish Süper Lig
# 1076   190              Italian Serie A
# 1077   448       Spain Primera Division
# 1078     8  English League Championship
# 1079  1799       English Premier League
#
# [1080 rows x 2 columns]

# %%
dataframe['City']
# Out:
# 0         Yangon
# 1      Naypyitaw
# 2         Yangon
# 3         Yangon
# 4         Yangon
#          ...
# 995    Naypyitaw
# 996     Mandalay
# 997       Yangon
# 998       Yangon
# 999       Yangon
# Name: City, Length: 1000, dtype: object

# %%
dataframe['Branch']
# Out:
# 0      A
# 1      C
# 2      A
# 3      A
# 4      A
#       ..
# 995    C
# 996    B
# 997    A
# 998    A
# 999    A
# Name: Branch, Length: 1000, dtype: object

# %%
print(dataframe.index)
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
dataframe[['City','Branch']]
# Out:
#           City Branch
# 0       Yangon      A
# 1    Naypyitaw      C
# 2       Yangon      A
# 3       Yangon      A
# 4       Yangon      A
# ..         ...    ...
# 995  Naypyitaw      C
# 996   Mandalay      B
# 997     Yangon      A
# 998     Yangon      A
# 999     Yangon      A
#
# [1000 rows x 2 columns]

# %%
for i in dataframe.index:
  print((dataframe.City[i],dataframe.Branch[i]))
# Out:
# ('Yangon', 'A')
# ('Naypyitaw', 'C')
# ('Yangon', 'A')
# ('Yangon', 'A')
# ('Yangon', 'A')
# ('Naypyitaw', 'C')
# ('Yangon', 'A')
# ('Naypyitaw', 'C')
# ('Yangon', 'A')
# ('Mandalay', 'B')
# ('Mandalay', 'B')
# ('Mandalay', 'B')
# ('Yangon', 'A')
# ('Yangon', 'A')
# ('Yangon', 'A')
# ('Mandalay', 'B')
# ('Yangon', 'A')
# ('Yangon', 'A')
# ('Yangon', 'A')
# ('Mandalay', 'B')
# ('Naypyitaw', 'C')
# ('Mandalay', 'B')
# ('Mandalay', 'B')
# ('Yangon', 'A')
# ('Yangon', 'A')
# ('Yangon', 'A')
# ('Mandalay', 'B')
# ('Yangon', 'A')
# ('Mandalay', 'B')
# ('Yangon', 'A')
# ('Mandalay', 'B')
# ('Mandalay', 'B')
# ('Mandalay', 'B')
# ('Yangon', 'A')
# ('Naypyitaw', 'C')
# ('Naypyitaw', 'C')
# ('Yangon', 'A')
# ('Yangon', 'A')
# ('Naypyitaw', 'C')
# ('Mandalay', 'B')
# ('Mandalay', 'B')
# ('Naypyitaw', 'C')
# ('Mandalay', 'B')
# ('Naypyitaw', 'C')
# ('Naypyitaw', 'C')
# ('Mandalay', 'B')
# ('Mandalay', 'B')
# ('Mandalay', 'B')
# ('Mandalay', 'B')
# ('Naypyitaw', 'C')
# ('Naypyitaw', 'C')
# ...

# %%
from google.colab import files
players=files.upload()
# Out:
#      <input type="file" id="files-ab5e2f91-1f95-412d-a453-a9b7d263ec93" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ab5e2f91-1f95-412d-a453-a9b7d263ec93">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
fifadataframe= pandas.read_csv("players_20.csv")
max_overall=fifadataframe.overall.max()
max_overall_loc = fifadataframe.overall.idxmax()
person=fifadataframe.loc[max_overall_loc]
print(person.long_name," has the highest overall of ",max_overall)
# Out:
# Lionel Andrés Messi Cuccittini  has the highest overall of  94

# %%
fifadataframe = pandas.read_csv("players_20.csv")
min_overall=fifadataframe.overall.min()
min_overall_loc = fifadataframe.overall.idxmin()
person=fifadataframe.loc[min_overall_loc]
print(person.long_name," has the highest overall of ",min_overall)
# Out:
# 陶强龙  has the highest overall of  48

# %%
fifadataframe = pandas.read_csv("players_20.csv")
max_age=fifadataframe.overall.max()
max_age_loc = fifadataframe.age.idxmax()
person=fifadataframe.loc[max_age_loc]
print(person.long_name," has the highest age of ",max_age)
# Out:
# Cristian Fernando Muñoz Hoffman  has the highest age of  94

# %%
playercount = fifadataframe.sofifa_id.count()
print(playercount)
# Out:
# 18278

# %%
for i in fifadataframe.index:
  if fifadataframe.club[i] == "FC Barcelona":
    print(fifadataframe.short_name[i])
# Out:
# L. Messi
# M. ter Stegen
# L. Suárez
# Sergio Busquets
# A. Griezmann
# Piqué
# Jordi Alba
# S. Umtiti
# I. Rakitić
# F. de Jong
# C. Lenglet
# Neto
# O. Dembélé
# Arthur
# A. Vidal
# Nélson Semedo
# Sergi Roberto
# Rafinha
# Junior Firpo
# Aleñá
# Riqui Puig
# J. Todibo
# M. Wagué
# H. Abe
# L. Reis
# Abel Ruiz
# Oriol Busquets
# Carles Pérez
# Miranda
# Chumi
# Álex Collado
# Jorge Cuenca
# Iñaki Peña
